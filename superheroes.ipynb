# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('charcters_stats.csv')
df
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 4        Abomination       bad            63        80     53          90
# ..               ...       ...           ...       ...    ...         ...
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
# 610             Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 0       25      52    233
# 1       17      64    316
# 2       35      85    299
# 3       84      65    406
# 4       55      95    436
# ..     ...     ...    ...
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292
# 610     72      28    288
#
# [611 rows x 9 columns]

# %% [markdown]
# ## Showing the first records of CSV file
# head() is used to show the first records
# Since there is no specific number of records specified, head will grab the first 5 records

# %%
df_res = df.head()
df_res
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 4  Abomination       bad            63        80     53          90     55
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 4      95    436

# %% [markdown]
# ## Shwoing number of rows and columns
# shape() is used to show (row, columns) number of a dataframe

# %%
df.shape
# Out:
# (611, 9)

# %% [markdown]
# ## Find values of alignments
# value_counts() can be used to easily count the number of differnt values in a series.
# dropna is set to False to include the number of empty (NaN) value

# %%
pd.DataFrame(df["Alignment"].value_counts(dropna=False))
# Out:
#          Alignment
# good           432
# bad            165
# neutral         11
# NaN              3

# %% [markdown]
# ## Shows only superheroes with good alignment
# Set specific column and its desired value to find in [] in the format of ["col_name"=="value"], then wrap the syntax in df[] to get the dataframe from resulting series

# %%
df[df["Alignment"] == "good"]
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 0            3-D Man      good            50        31     43          32
# 1             A-Bomb      good            38       100     17          80
# 2         Abe Sapien      good            88        14     35          42
# 3           Abin Sur      good            50        90     53          64
# 6        Adam Monroe      good            63        10     12         100
# ..               ...       ...           ...       ...    ...         ...
# 604            X-Man      good            88        53     53          95
# 606     Yellowjacket      good            88        10     12          28
# 607  Yellowjacket II      good            50        10     35          28
# 608             Ymir      good            50       100     27         100
# 609          Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 0       25      52    233
# 1       17      64    316
# 2       35      85    299
# 3       84      65    406
# 6       71      64    320
# ..     ...     ...    ...
# 604     92      84    465
# 606     12      14    164
# 607     31      28    182
# 608     83      28    388
# 609    100      56    292
#
# [432 rows x 9 columns]

# %% [markdown]
# ## Shows first five superheroes with good alignment
# Use head and pass the number of records desired to the dataframe above

# %%
df[df["Alignment"] == "good"].head(5)
# Out:
#           Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 0      3-D Man      good            50        31     43          32     25
# 1       A-Bomb      good            38       100     17          80     17
# 2   Abe Sapien      good            88        14     35          42     35
# 3     Abin Sur      good            50        90     53          64     84
# 6  Adam Monroe      good            63        10     12         100     71
#
#    Combat  Total
# 0      52    233
# 1      64    316
# 2      85    299
# 3      65    406
# 6      64    320

# %% [markdown]
# ## Show five reocrds of super heroes who have top speed of good alignment
# From dataframe of last prompt (superheroes with good alignment), use sort_values and define column to sort and descended order of sorting. Then use head() to get the top 5 records

# %%
df[df["Alignment"] == "good"].sort_values(by=['Speed'],ascending=False).head(5)
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 231       Flash III      good            63        10    100          60
# 304  Jack of Hearts      good            63        55    100          30
# 295         Impulse      good            50        10    100          60
# 525        Stardust      good            88        85    100         110
# 447     Quicksilver      good            63        28    100          60
#
#      Power  Combat  Total
# 231     83      32    348
# 304     70      30    348
# 295     63      60    343
# 525    100      85    568
# 447     57      56    364

# %% [markdown]
# ## Show five reocrds of super  heroes who have max power of good alignment
# From dataframe of last prompt (superheroes with good alignment), use sort_values and define column to sort and descended order of sorting. Then use head() to get the top 5 records

# %%
df[df["Alignment"] == "good"].sort_values(by=['Power'],ascending=False).head(5)
# Out:
#               Name Alignment  Intelligence  Strength  Speed  Durability  \
# 609        Zatanna      good            75        10     23          28
# 546           Thor      good            69       100     92         100
# 511          Spawn      good            75        60     50          90
# 69   Beta Ray Bill      good            63        80     35          95
# 70        Beyonder      good            88       100     23         100
#
#      Power  Combat  Total
# 609    100      56    292
# 546    100      85    546
# 511    100      95    470
# 69     100      84    457
# 70     100      56    467

# %% [markdown]
# ## Find out how many super heroes are there with power 100 of good alignment
# Use loc to filter dataframe and get the records that satisfy the conditions (power = 100 and alignment = good), then use len to get number of records in the output dataframe

# %%
df_res = df.loc[(df["Alignment"] == "good") & (df["Power"]==100)]
len(df_res)
# Out:
# 33

# %% [markdown]
# ## Shape the result above (prompt 10)
# Use df.shape to get the shape dimensionality. Returns number of rows and number of columns of the dataframe that called the property

# %%
df_res.shape
# Out:
# (33, 9)

# %% [markdown]
# ## Show all records from point 10

# %%
df_res
# Out:
#                   Name Alignment  Intelligence  Strength  Speed  Durability  \
# 69       Beta Ray Bill      good            63        80     35          95
# 70            Beyonder      good            88       100     23         100
# 85          Black Bolt      good            75        67    100          84
# 129              Cable      good            88        48     23          56
# 185            Deadman      good            50        10     33         100
# 196        Doctor Fate      good            81        16     25          80
# 198     Doctor Strange      good           100        10     12          84
# 204       Dr Manhattan      good            88        32     42          95
# 226          Firestorm      good            50        53     58          56
# 251               Goku      good            56       100     75          90
# 266         Hal Jordan      good            63        90     53          64
# 294             Iceman      good            63        32     53         100
# 299           Iron Man      good           100        85     58          85
# 306          Jean Grey      good           100        80     67         100
# 327            Kilowog      good            81        90     53          42
# 361  Martian Manhunter      good           100       100     96         100
# 362        Marvel Girl      good            63        85     47          42
# 383       Miss Martian      good            63        85     58         100
# 408     Naruto Uzumaki      good            50        80     32          80
# 417               Nova      good           100        85     67         101
# 418               Nova      good            38        60    100         100
# 419          Offspring      good            50        10     35          99
# 433            Phoenix      good           100        80     67         100
# 435        Plastic Man      good            50        63     23         100
# 487        Shadow King      good            75        12     27         100
# 499      Silver Surfer      good            63       100     84         101
# 511              Spawn      good            75        60     50          90
# 525           Stardust      good            88        85    100         110
# 546               Thor      good            69       100     92         100
# 547          Thor Girl      good            75        83     70          84
# 583        War Machine      good            63        80     63         100
# 589            Watcher      good           100        80     67          89
# 609            Zatanna      good            75        10     23          28
#
#      Power  Combat  Total
# 69     100      84    457
# 70     100      56    467
# 85     100      56    482
# 129    100      80    395
# 185    100      42    335
# 196    100      50    352
# 198    100      60    366
# 204    100      42    399
# 226    100      42    359
# 251    100     100    521
# 266    100      56    426
# 294    100      64    412
# 299    100      64    492
# 306    100      70    517
# 327    100      80    446
# 361    100      85    581
# 362    100      80    417
# 383    100      45    451
# 408    100     100    442
# 417    100      85    538
# 418    100      25    423
# 419    100      56    350
# 433    100      70    517
# 435    100      56    392
# 487    100      75    389
# 499    100      32    480
# 511    100      95    470
# 525    100      85    568
# 546    100      85    546
# 547    100      70    482
# 583    100      85    491
# 589    100      56    492
# 609    100      56    292

# %% [markdown]
# ## Retrieve total of first 5 records of max power of good alignment superheroes
# Use nlarges and pass arguments (number of rows to return, columns label for the output to be ordered by)

# %%
df_res=df[['Name','Total','Power']].loc[ (df['Alignment']=='good') ].nlargest(5, 'Power')
df_res
# Out:
#               Name  Total  Power
# 69   Beta Ray Bill    457    100
# 70        Beyonder    467    100
# 85      Black Bolt    482    100
# 129          Cable    395    100
# 185        Deadman    335    100

# %% [markdown]
# ## Draw bar plot of all superheroes with good alignment and max power of top 5, use object of prompt 13
# Use df.sort_values to grab the dataframe of superheroes with good alignment, max power and top 5 highest total power. Then use plot.bar to draw the bar plot.

# %%
df_res=df[['Name','Total','Power']].loc[ (df['Alignment']=='good') ].sort_values(by=['Total'],ascending=False).head(5)
power = df_res['Total']
superhero_name = df_res['Name']
plt.bar(superhero_name,power, color = 'green')
plt.xticks(rotation = 90)
plt.title("Power of superheroes with max power")
plt.xlabel("Name")
plt.ylabel("Total Power level")
plt.show()

# %% [markdown]
# ## Extract villians with bad alignment
# Use df.loc to filter dataframe and get the records that satisfy the conditions (alignment = bad)

# %%
df_res = df.loc[(df["Alignment"] == "bad")]
df_res
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 4       Abomination       bad            63        80     53          90
# 5           Abraxas       bad            88       100     83          99
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 17             Ammo       bad             1         1      1           1
# ..              ...       ...           ...       ...    ...         ...
# 586            Warp       bad            38        10     23          28
# 590       Weapon XI       bad             1         1      1           1
# 593  Willis Stryker       bad            38        16     23          28
# 605     Yellow Claw       bad             1         1      1           1
# 610            Zoom       bad            50        10    100          28
#
#      Power  Combat  Total
# 4       55      95    436
# 5      100      56    526
# 11     100      40    460
# 16     100     100    575
# 17       0       1      5
# ..     ...     ...    ...
# 586     63      50    212
# 590      0       1      5
# 593     41      60    206
# 605      0       1      5
# 610     72      28    288
#
# [165 rows x 9 columns]

# %% [markdown]
# ## Show first five records of villians with bad alignment (prompt 15)
# Use head() to get the first 5 records of the dataframe

# %%
df_res.head(5)
# Out:
#            Name Alignment  Intelligence  Strength  Speed  Durability  Power  \
# 4   Abomination       bad            63        80     53          90     55
# 5       Abraxas       bad            88       100     83          99    100
# 11   Air-Walker       bad            50        85    100          85    100
# 16        Amazo       bad            75       100    100         100    100
# 17         Ammo       bad             1         1      1           1      0
#
#     Combat  Total
# 4       95    436
# 5       56    526
# 11      40    460
# 16     100    575
# 17       1      5

# %% [markdown]
# ## Show top 5 fastest villains in terms of speed
# Use df.nlargest to get the top 5 fastest villains in terms of speed. Sort by speed and descending order.

# %%
df.loc[(df["Alignment"] == "bad")].nlargest(5, "Speed")
# Out:
#                Name Alignment  Intelligence  Strength  Speed  Durability  \
# 11       Air-Walker       bad            50        85    100          85
# 16            Amazo       bad            75       100    100         100
# 535  Superboy-Prime       bad            94       100    100         100
# 610            Zoom       bad            50        10    100          28
# 242     General Zod       bad            94       100     96         100
#
#      Power  Combat  Total
# 11     100      40    460
# 16     100     100    575
# 535    100      85    579
# 610     72      28    288
# 242     94      95    579

# %% [markdown]
# ## Show top 5 fastest villains in terms of intelligence
# Use df.nlargest to get the top 5 fastest villains in terms of intelligence. Sort by intelligence and descending order.

# %%
df.loc[(df["Alignment"] == "bad")].nlargest(5, "Intelligence")
# Out:
#                 Name Alignment  Intelligence  Strength  Speed  Durability  \
# 386  Mister Mxyzptlk       bad           113        10     12          14
# 29        Apocalypse       bad           100       100     33         100
# 122         Brainiac       bad           100        28     63          90
# 194      Doctor Doom       bad           100        32     20         100
# 315            Joker       bad           100        10     12          56
#
#      Power  Combat  Total
# 386    100      28    277
# 29     100      60    493
# 122     60      75    416
# 194     93      84    429
# 315     22      90    290

# %% [markdown]
# ## Show who is the most dangerous villain after calculating their total (top 5 only)
# Use df.nlargest to get the top 5 fastest villains in terms of total. Sort by total and descending order.

# %%
df[["Name","Total"]].loc[ (df['Alignment']=='bad') ].nlargest(5, 'Total')
# Out:
#                Name  Total
# 242     General Zod    579
# 535  Superboy-Prime    579
# 16            Amazo    575
# 203        Dormammu    546
# 201        Doomsday    545

# %% [markdown]
# ## Histogram of

# %% [markdown]
# ## Histogram of
